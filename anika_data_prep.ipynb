# %%
# %pip install python-docx pdfplumber spacy langchain tiktoken
# !python -m spacy download en_core_web_sm
# Out:
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Collecting python-docx
#   Downloading python_docx-1.1.0-py3-none-any.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.6/239.6 kB 4.0 MB/s eta 0:00:00
# Collecting pdfplumber
#   Downloading pdfplumber-0.10.3-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.0/49.0 kB 6.5 MB/s eta 0:00:00
# Collecting spacy
#   Downloading spacy-3.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 75.3 MB/s eta 0:00:00
# Collecting langchain
#   Downloading langchain-0.0.350-py3-none-any.whl (809 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.1/809.1 kB 49.6 MB/s eta 0:00:00
# Collecting tiktoken
#   Downloading tiktoken-0.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 70.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /databricks/python3/lib/python3.10/site-packages (from python-docx) (4.3.0)
# Collecting lxml>=3.1.0
#   Downloading lxml-4.9.3-cp310-cp310-manylinux_2_28_x86_64.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 68.1 MB/s eta 0:00:00
# Collecting pdfminer.six==20221105
#   Downloading pdfminer.six-20221105-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 85.5 MB/s eta 0:00:00
# Requirement already satisfied: Pillow>=9.1 in /databricks/python3/lib/python3.10/site-packages (from pdfplumber) (9.2.0)
# Collecting pypdfium2>=4.18.0
#   Downloading pypdfium2-4.25.0-py3-none-manylinux_2_17_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 81.4 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /databricks/python3/lib/python3.10/site-packages (from pdfminer.six==20221105->pdfplumber) (2.0.4)
# Requirement already satisfied: cryptography>=36.0.0 in /databricks/python3/lib/python3.10/site-packages (from pdfminer.six==20221105->pdfplumber) (37.0.1)
# Requirement already satisfied: jinja2 in /databricks/python3/lib/python3.10/site-packages (from spacy) (2.11.3)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 5.7 MB/s eta 0:00:00
# Collecting thinc<8.3.0,>=8.1.8
#   Downloading thinc-8.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (920 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 920.6/920.6 kB 55.0 MB/s eta 0:00:00
# Collecting weasel<0.4.0,>=0.1.0
#   Downloading weasel-0.3.4-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 6.8 MB/s eta 0:00:00
# Collecting tqdm<5.0.0,>=4.38.0
#   Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 10.6 MB/s eta 0:00:00
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 kB 22.3 MB/s eta 0:00:00
# Collecting smart-open<7.0.0,>=5.2.1
#   Downloading smart_open-6.4.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /databricks/python3/lib/python3.10/site-packages (from spacy) (2.28.1)
# Requirement already satisfied: packaging>=20.0 in /databricks/python3/lib/python3.10/site-packages (from spacy) (21.3)
# Requirement already satisfied: numpy>=1.19.0 in /databricks/python3/lib/python3.10/site-packages (from spacy) (1.21.5)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.9-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.9/156.9 kB 18.8 MB/s eta 0:00:00
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: setuptools in /databricks/python3/lib/python3.10/site-packages (from spacy) (63.4.1)
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (493 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.0/493.0 kB 28.9 MB/s eta 0:00:00
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /databricks/python3/lib/python3.10/site-packages (from spacy) (1.10.6)
# Collecting wasabi<1.2.0,>=0.9.1
#   Downloading wasabi-1.1.2-py3-none-any.whl (27 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Collecting typer<0.10.0,>=0.3.0
#   Downloading typer-0.9.0-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 5.5 MB/s eta 0:00:00
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.10-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Collecting langchain-community<0.1,>=0.0.2
#   Downloading langchain_community-0.0.3-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 59.8 MB/s eta 0:00:00
# Collecting aiohttp<4.0.0,>=3.8.3
#   Downloading aiohttp-3.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 56.0 MB/s eta 0:00:00
# Collecting jsonpatch<2.0,>=1.33
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting langchain-core<0.2,>=0.1
#   Downloading langchain_core-0.1.0-py3-none-any.whl (189 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.1/189.1 kB 22.7 MB/s eta 0:00:00
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /databricks/python3/lib/python3.10/site-packages (from langchain) (8.1.0)
# Collecting async-timeout<5.0.0,>=4.0.0
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting SQLAlchemy<3,>=1.4
#   Downloading SQLAlchemy-2.0.23-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 94.1 MB/s eta 0:00:00
# Collecting langsmith<0.1.0,>=0.0.63
#   Downloading langsmith-0.0.69-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 6.6 MB/s eta 0:00:00
# Collecting PyYAML>=5.3
#   Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.5/705.5 kB 49.3 MB/s eta 0:00:00
# Collecting dataclasses-json<0.7,>=0.5.7
#   Downloading dataclasses_json-0.6.3-py3-none-any.whl (28 kB)
# Collecting regex>=2022.1.18
#   Downloading regex-2023.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (773 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 773.9/773.9 kB 56.1 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 15.6 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /databricks/python3/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (21.4.0)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.6/301.6 kB 32.6 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.4.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (225 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.7/225.7 kB 23.7 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting marshmallow<4.0.0,>=3.18.0
#   Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.0 MB/s eta 0:00:00
# Collecting jsonpointer>=1.9
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Collecting anyio<5,>=3
#   Downloading anyio-4.1.0-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.9/83.9 kB 10.7 MB/s eta 0:00:00
# Collecting packaging>=20.0
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /databricks/python3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.11)
# Collecting greenlet!=0.4.17
#   Downloading greenlet-3.0.2-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (613 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.4/613.4 kB 47.6 MB/s eta 0:00:00
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 85.4 MB/s eta 0:00:00
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.1.4-py3-none-any.whl (35 kB)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /databricks/python3/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Collecting cloudpathlib<0.17.0,>=0.7.0
#   Downloading cloudpathlib-0.16.0-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=0.23 in /databricks/python3/lib/python3.10/site-packages (from jinja2->spacy) (2.0.1)
# Collecting exceptiongroup>=1.0.2
#   Downloading exceptiongroup-1.2.0-py3-none-any.whl (16 kB)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: cffi>=1.12 in /databricks/python3/lib/python3.10/site-packages (from cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber) (1.15.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /databricks/python3/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (0.4.3)
# Requirement already satisfied: pycparser in /databricks/python3/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber) (2.21)
# Installing collected packages: cymem, wasabi, typing-inspect, typer, tqdm, spacy-loggers, spacy-legacy, sniffio, smart-open, regex, PyYAML, pypdfium2, packaging, murmurhash, multidict, lxml, langcodes, jsonpointer, greenlet, frozenlist, exceptiongroup, cloudpathlib, catalogue, blis, async-timeout, yarl, tiktoken, srsly, SQLAlchemy, python-docx, preshed, marshmallow, langsmith, jsonpatch, anyio, aiosignal, pdfminer.six, langchain-core, dataclasses-json, confection, aiohttp, weasel, thinc, pdfplumber, langchain-community, spacy, langchain
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Not uninstalling packaging at /databricks/python3/lib/python3.10/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-04cc8aea-1c5c-45fb-abc7-a439e1598fb0
#     Can't uninstall 'packaging'. No files were found to uninstall.
# Successfully installed PyYAML-6.0.1 SQLAlchemy-2.0.23 aiohttp-3.9.1 aiosignal-1.3.1 anyio-4.1.0 async-timeout-4.0.3 blis-0.7.11 catalogue-2.0.10 cloudpathlib-0.16.0 confection-0.1.4 cymem-2.0.8 dataclasses-json-0.6.3 exceptiongroup-1.2.0 frozenlist-1.4.0 greenlet-3.0.2 jsonpatch-1.33 jsonpointer-2.4 langchain-0.0.350 langchain-community-0.0.3 langchain-core-0.1.0 langcodes-3.3.0 langsmith-0.0.69 lxml-4.9.3 marshmallow-3.20.1 multidict-6.0.4 murmurhash-1.0.10 packaging-23.2 pdfminer.six-20221105 pdfplumber-0.10.3 preshed-3.0.9 pypdfium2-4.25.0 python-docx-1.1.0 regex-2023.10.3 smart-open-6.4.0 sniffio-1.3.0 spacy-3.7.2 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.2.1 tiktoken-0.5.2 tqdm-4.66.1 typer-0.9.0 typing-inspect-0.9.0 wasabi-1.1.2 weasel-0.3.4 yarl-1.9.4
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 74.7 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-04cc8aea-1c5c-45fb-abc7-a439e1598fb0/lib/python3.10/site-packages (from en-core-web-sm==3.7.1) (3.7.2)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-04cc8aea-1c5c-45fb-abc7-a439e1598fb0/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-04cc8aea-1c5c-45fb-abc7-a439e1598fb0/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: packaging>=20.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-04cc8aea-1c5c-45fb-abc7-a439e1598fb0/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.2)
# Requirement already satisfied: setuptools in /databricks/python3/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (63.4.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-04cc8aea-1c5c-45fb-abc7-a439e1598fb0/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-04cc8aea-1c5c-45fb-abc7-a439e1598fb0/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-04cc8aea-1c5c-45fb-abc7-a439e1598fb0/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-04cc8aea-1c5c-45fb-abc7-a439e1598fb0/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-04cc8aea-1c5c-45fb-abc7-a439e1598fb0/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /databricks/python3/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.10.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /databricks/python3/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.28.1)
# Requirement already satisfied: jinja2 in /databricks/python3/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.11.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-04cc8aea-1c5c-45fb-abc7-a439e1598fb0/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-04cc8aea-1c5c-45fb-abc7-a439e1598fb0/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-04cc8aea-1c5c-45fb-abc7-a439e1598fb0/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-04cc8aea-1c5c-45fb-abc7-a439e1598fb0/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.1)
# Requirement already satisfied: numpy>=1.19.0 in /databricks/python3/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.21.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-04cc8aea-1c5c-45fb-abc7-a439e1598fb0/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-04cc8aea-1c5c-45fb-abc7-a439e1598fb0/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-04cc8aea-1c5c-45fb-abc7-a439e1598fb0/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /databricks/python3/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /databricks/python3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /databricks/python3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-04cc8aea-1c5c-45fb-abc7-a439e1598fb0/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-04cc8aea-1c5c-45fb-abc7-a439e1598fb0/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /databricks/python3/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-04cc8aea-1c5c-45fb-abc7-a439e1598fb0/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /databricks/python3/lib/python3.10/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.1)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.7.1
#
# [notice] A new release of pip available: 22.2.2 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
dbutils.library.restartPython()

# %%
import re
import json
import time
import requests
import spacy
from docx import Document
import pdfplumber
from langchain.embeddings import AzureOpenAIEmbeddings

# %%
# Extracts regular docx files and chunks them by their headers into a list

def is_header_docx(paragraph):
    # Check if the paragraph style is a header style
    if paragraph.style:
        if paragraph.style.name.startswith('Heading'):
            return True
        
    # Check if the paragraph is italicized/underlined/bold and ends with ':'
    if paragraph.text.endswith(':'):
        if any(run.bold for run in paragraph.runs) or \
           any(run.italic for run in paragraph.runs) or \
           any(run.underline for run in paragraph.runs):
            return True

    return False

def extract_docx(path):
    # Load the document
    doc = Document(path)
    content = []
    current_header = ""
    header_content = ""

    # Iterate through all paragraphs in the document
    for para in doc.paragraphs:
        if is_header_docx(para):
            # Process the accumulated text if any exists
            if header_content:
                # Split the text into sentences and append to content list
                sentences = re.split(r'(?<=[.!?])\s+', header_content)
                for sentence in sentences:
                    content.append(f'{current_header} - {sentence}')

            # Update the current header and reset the header content
            current_header = para.text.strip()
            header_content = ""
        else:
            # Accumulate text under the current header
            header_content += para.text + " "

    # Process any remaining text after the last paragraph
    if header_content:
        sentences = re.split(r'(?<=[.!?])\s+', header_content)
        for sentence in sentences:
            content.append(f'{current_header} - {sentence}')

    return content

bug_reporting_text = extract_docx("/dbfs/mnt/anikadata/Bug Reporting Directions.docx")
bug_reporting_text
# Out:
# ['Creating Bug Reports (COE-KG-XXX) - Bugs are deviations or defects noted in the deployment or end-state of a system.',
#  'Creating Bug Reports (COE-KG-XXX) - They can be anything from a minor inconvenience to potentially catastrophic failure points.',
#  'Creating Bug Reports (COE-KG-XXX) - This article will guide you on how to go about handling bugs and the creation of bug reports in user stories.',
#  'Creating Bug Reports (COE-KG-XXX) - ',
#  'Steps to Reproduce - Indicates all the details we need in order to see the bug.',
#  'Steps to Reproduce - For instance, by including screenshots and writing down the steps to recreate the issue we are able to allocate the right resources and assign the bug to the correct team.',
#  'Steps to Reproduce - The Steps to Reproduce or Recreate should be a numbered list of the steps that you took to notice the problem.',
#  'Steps to Reproduce - The person who opens the bug report will try these steps and fix the problem if they can see it.',
#  'Steps to Reproduce - However, if they cannot, there is nothing they can do.',
#  'Steps to Reproduce - This first step is called "replicating a bug." The actions you describe are vital to ensuring that you can replicate bugs before fixing them.',
#  'Steps to Reproduce - An example of Steps to Reproduce might look like this:  Uncomment the agent extension code at the bottom of the\xa0linuxVirtualMachine module\xa0 Deploy the VDC / Landing Zone structure Deploy the linuxVirtualMachine module, or the 2tier-linux-app into a landing zone ',
#  'Note the Expected vs. Actual Behavior - As the title explains, within a bug report there should be a section where you describe what the expected behavior of a particular section of code/system should be.',
#  'Note the Expected vs. Actual Behavior - And in contrast, you should write a section explaining the actual outcome/result of executing the section of code.',
#  'Note the Expected vs. Actual Behavior - An example of Expected vs.',
#  'Note the Expected vs. Actual Behavior - Actual Behavior may be :  Expected Behavior:\xa0 Module Completes successfully\xa0 Log data from the VMs w/in 2tier-linux-app is supplied to LAW via OMS/ AMA agent Actual Behavior:\xa0 Module reports failure during installation of VM extension\xa0 You should experience the deployment hang-up on the 2 extension installs, never completing An error message indicating failure to list keys for LAW will be present  ',
#  'Include Screenshots / Error Messages in a Bug Report - Screenshots/error message capturing is a critical piece of a bug report because it shows:  Proof you observed the problem  A general location/starting point to investigate the issue  ',
#  'Example : -  ',
#  'Prioritize / Estimate Bugs - We cannot always determine the period of repairing something that is broken in an unknown way.',
#  'Prioritize / Estimate Bugs - Therefore, we estimate and prioritize the defect list into three main categories: The 3 Priorities:  High - bugs that are affecting the core functionalities of the product Medium - bugs that have a workaround, but degrade the core functionalities of the product  Low - bugs that do not affect critical / core functions of the product, usually for cosmetic purpose ',
#  'Scenarios: - Below are two example scenarios for handling the defects, by either assigning a time window or refinement and estimation: Scenario 1: Assign the timebox to the bugs.',
#  'Scenarios: - The team assigns a fixed number of hours dedicated to working on the bugs, servicing them based on the top priority within the list of bugs.',
#  'Scenarios: - In this scenario, the team can handle one bug or five or an unlimited amount of bugs.',
#  'Scenarios: - There is no prediction on how many bugs the team can do and no commitment to the delivery time.',
#  'Scenarios: - But, at the same time, there is no time lost in investigating the bugs.',
#  'Scenarios: - Scenario 2: Refine the bugs and estimate them in user stories.',
#  'Scenarios: - For clarification, the bugs are the misfunctioning of the product.',
#  'Scenarios: - Functionalities that aren’t present in the product, must be handled with user stories, not with bugs.',
#  'Scenarios: - The nature of the flaws in software is very uncertain: they can take a few minutes, as they can take an unestimated amount of time.',
#  'Scenarios: - It might take more effort to find the root cause of a bug than actually fix it.',
#  'Scenarios: - If you want to estimate a bug, you first need to investigate the issue, look into the code, debug, and isolate the problem.',
#  'Scenarios: - If the team spends this effort during the refinement processes and the entire team is involved, it might be a waste of team effort.',
#  'Scenarios: - ',
#  'Example of Good Bug Report: -  ',
#  'Examples of Bad Bug Report: -  ']

# %%
# Specialized extraction for Docx Files with tables (was not extracting properly with above function)

def extract_docx_tables(path):
    # Load the document
    doc = Document(path)
    content = []

    # Iterate through all elements in the document body
    for element in doc.element.body:
        # Check if the current element is a paragraph
        if element.tag.endswith('p'):
            # Add the paragraph text to the content list, stripping leading/trailing whitespace
            content.append(element.text.strip())

        # Check if the current element is a table
        elif element.tag.endswith('tbl'):
            # Iterate through all rows in the table
            for row in element.findall('.//w:tr', doc.element.nsmap):
                row_data = []
                # Iterate through all cells in the current row
                for cell in row.findall('.//w:tc', doc.element.nsmap):
                    # Extract and concatenate text from each XML node inside the cell
                    cell_text = ''.join(node.text for node in cell.findall('.//w:t', doc.element.nsmap))
                    row_data.append(cell_text.strip())

                content.append(' | '.join(row_data))

    return content

federal_holidays_text = extract_docx_tables("/dbfs/mnt/anikadata/Federal Holidays 2023 - 2024.docx")
federal_holidays_text
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Federal Holiday Schedule',
#  '2023 - 2024',
#  '',
#  '2023',
#  '2023 Holiday Schedule',
#  'Date | Holiday',
#  'Monday, January 02 * | New Year’s Day',
#  'Monday, January 16 | Birthday of Martin Luther King, Jr.',
#  'Monday, February 20 ** | Washington’s Birthday',
#  'Monday, May 29 | Memorial Day',
#  'Monday, June 19 | Juneteenth National Independence Day',
#  'Tuesday, July 04 | Independence Day',
#  'Monday, September 04 | Labor Day',
#  'Monday, October 09 | Columbus Day',
#  'Friday, November 10 * | Veterans Day',
#  'Thursday, November 23 | Thanksgiving Day',
#  'Monday, December 25 | Christmas Day',
#  '*If a holiday falls on a Saturday, for most Federal employees, the preceding Friday will be treated as a holiday for pay and leave purposes. (See 5 U.S.C. 6103(b).) If a holiday falls on a Sunday, for most Federal employees, the following Monday will be treated as a holiday for pay and leave purposes. (See Section 3(a) of Executive Order 11582, February 11, 1971.) See also our Federal Holidays – "In Lieu Of" Determination Fact Sheet at https://www.opm.gov/policy-data-oversight/pay-leave/work-schedules/fact-sheets/Federal-Holidays-In-Lieu-Of-Determination.',
#  '**This holiday is designated as "Washington’s Birthday" in section 6103(a) of title 5 of the United States Code, which is the law that specifies holidays for Federal employees. Though other institutions such as state and local governments and private businesses may use other names, it is our policy to always refer to holidays by the names designated in the law.',
#  '',
#  '2024',
#  '2024 Holiday Schedule',
#  'Date | Holiday',
#  'Monday, January 01 | New Year’s Day',
#  'Monday, January 15 | Birthday of Martin Luther King, Jr.',
#  'Monday, February 19 * | Washington’s Birthday',
#  'Monday, May 27 | Memorial Day',
#  'Wednesday, June 19 | Juneteenth National Independence Day',
#  'Thursday, July 04 | Independence Day',
#  'Monday, September 02 | Labor Day',
#  'Monday, October 14 | Columbus Day',
#  'Monday, November 11 | Veterans Day',
#  'Thursday, November 28 | Thanksgiving Day',
#  'Wednesday, December 25 | Christmas Day',
#  '*This holiday is designated as "Washington’s Birthday" in section 6103(a) of title 5 of the United States Code, which is the law that specifies holidays for Federal employees. Though other institutions such as state and local governments and private businesses may use other names, it is our policy to always refer to holidays by the names designated in the law.',
#  '']

# %%
# Extracts pdf files and chunks them by their headers into a list

def is_header_pdf(line):
    # Enhanced header check: includes numbered headers and specific patterns
    numbered_header_pattern = r'^(?:[IVXLCDM]+\.\s+|[A-Z]+\.)'
    if re.match(numbered_header_pattern, line) or line.isupper() or line.istitle():
        return line
    return None

def is_end_of_sentence(line):
    return re.search(r'[.!?]$', line.strip()) is not None

def extract_pdf(path):
    sections = []
    current_header = ""
    header_content = ""

    with pdfplumber.open(path) as pdf:
        # Iterate through each page in the PDF
        for page in pdf.pages:
            page_text = page.extract_text()
            # Skip the page if no text is found
            if not page_text:
                continue

            # Split the page text into lines
            lines = page_text.split('\n')
            for line in lines:
                line = line.strip()
                # Check if the line is a header
                if is_header_pdf(line):
                    if current_header and header_content:
                        # Split the text into sentences and add to the sections list
                        sentences = re.split(r'(?<=[.!?])\s+', header_content)
                        for sentence in sentences:
                            sections.append(f'{current_header} - {sentence}')

                    # Update the current header and reset the text buffer
                    current_header = line
                    header_content = ""
                elif current_header is not None:
                    if not is_end_of_sentence(header_content) and header_content:
                        header_content += ' ' + line
                    else:
                        header_content += line

            # Process any remaining text after the last line on the page
            if current_header and header_content:
                sentences = re.split(r'(?<=[.!?])\s+', header_content)
                for sentence in sentences:
                    sections.append(f'{current_header} - {sentence}')

    return sections

benefit_guide_text = extract_pdf("/dbfs/mnt/anikadata/Sample Benefit Guide.pdf")
employee_handbook_text = extract_pdf("/dbfs/mnt/anikadata/Sample Employee Handbook.pdf")
training_policy_text = extract_pdf("/dbfs/mnt/anikadata/Sample Training Development Policy.pdf")

benefit_guide_text
# Out:
# ['Your Decision - 2017',
#  'Medical - Medical Carrier 800-244-6224 www.medical.com',
#  'Dental - Dental Carrier 800-244-6224 www.dental.com',
#  'Vision - Vision Carrier 866-723-0513 www.vision.com',
#  'Flexible Spending Accounts - FSA Carrier 800-422-4661 www.fsa.com',
#  'Short Term & Long Term Disability - and Life Insurance Disability & Life Carrier 800-362-4462 www.dilife.com',
#  'Voluntary Benefits - Trustmark 800-918-8877 www.trustmarksolutions.com Transamerica 888-763-7474 www.transamericaemployeebenefits.com',
#  'Identity Theft - LifeLock www.lifelock.com',
#  'Pet Insurance - Pet Insurance Carrier 877-738-7874 www.pets.com',
#  'Employee Assistance Plan - EE Assistance Carrier 877-622-4327 www.eea.com Florida Retirement System (FRS) EE Hotline: 866-446-9377 www.myfrs.com',
#  'Calculations: 888-738-2252 - HR Hotline 941-429-7200 hrservices@abccompany.com',
#  'Help - Explain My Benefits 888-734-6937 Opt.',
#  'Help - 2 service@explainmybenefits.biz All benefits in this booklet are subject to change.',
#  'Help - This is an Employee Benefits Guide and not a contract.',
#  'Help - All benefits are subject to the provisions and exclusions of the master contract.',
#  'Help - 18',
#  'Help - Explain My Benefits 888-734-6937 Opt.',
#  'Help - 2 service@explainmybenefits.biz All benefits in this booklet are subject to change.',
#  'Help - This is an Employee Benefits Guide and not a contract.',
#  'Help - All benefits are subject to the provisions and exclusions of the master contract.',
#  'Help - 18 Table of Contents',
#  'Voluntary Benefits 19 - 21 - LifeLock 22 VPI - Veterinary Pet Insurance 23',
#  'Glossary 24 - All benefits in this booklet are subject to change.',
#  'Glossary 24 - This is an Employee Benefits Guide and not a contract.',
#  'Glossary 24 - All benefits are subject to the provisions and exclusions of the master contract.',
#  'Glossary 24 - All benefits in this booklet are subject to change.',
#  'Glossary 24 - This is an Employee Benefits Guide and not a contract.',
#  'Glossary 24 - All benefits are subject to the provisions and exclusions of the master contract.',
#  'Online Benefit Enrollment - The company will continue to provide electronic enrollment through Explain My Benefits.',
#  'Online Benefit Enrollment - Explain My Benefits provides benefit eligible employees the ability to make group insurance benefit elections and changes online during the annual open enrollment, new hire orientation and qualifying events.',
#  'Online Benefit Enrollment - Open enrollment has never been easier.',
#  'Online Benefit Enrollment - Accessible 24 hours a day during the open enrollment process, information about all of your employee benefits election options, including premiums and carrier contact information, are also available to help you make informed decisions.',
#  'Online Benefit Enrollment - You can also log on to the Explain My Benefits portal at any time to review your benefits, access carrier links, update life insurance beneficiaries, and report qualifying events.',
#  'August 21 - September 4 - EMB Enroll will be available for self-enrollment using any computer with access to the internet.',
#  'September 1 - September 2 - EMB benefit counselors will be on-site at Room A from 9:00am - 5:00pm, to assist employees that need help and answer questions.',
#  'September 1 - September 2 - There will be computers accessible to complete your enrollment.',
#  'September 1 - September 2 - To schedule a time for a counseling or kiosk session, go to www.explainmybenefits.biz/abc and click the button for the type of session you want.',
#  'Accessing Explain My Benefits Portal: - 1.',
#  'Accessing Explain My Benefits Portal: - Log on to www.explainmybenefits.biz/abc 2.',
#  'Accessing Explain My Benefits Portal: - Click the Green Enroll Button at the Right of the Page.3.',
#  'Accessing Explain My Benefits Portal: - Enter Explain My Benefits to review current elections, learn about your benefit options, and make any elections or changes.4.',
#  'Accessing Explain My Benefits Portal: - You may also update your life insurance beneficiary designation(s).5.',
#  'Accessing Explain My Benefits Portal: - You have the option to print out your enrollment summary statement containing all your benefit elections for you and your family including your life insurance beneficiary designations.6.',
#  'Accessing Explain My Benefits Portal: - If you have questions or need assistance with your enrollment, please see a Benefit Counselor on the dates and time listed above or call the Explain My Benefits Call Center at 321-296-8060, Option 1 between 9:00am - 5:00pm, Monday through Friday.',
#  'DEPENDENT INFORMATION - If you intend to elect ANY benefit for your spouse and/or eligible dependents, they must be listed as dependents in the system and you MUST have their SSN to input into the system.',
#  'DEPENDENT INFORMATION - You will not be able to proceed with your enrollment and confirm your elections without inputting the SSN’s for your spouse and/or dependents.',
#  'DEPENDENT INFORMATION - Spouse, Children and Family coverage levels will not be available for you to select if the dependent information is not present.For more information about your Benefits Enrollment please visit: www.explainmybenefits.biz/abc Everyone must complete the online enrollment process, whether you are electing benefits, keeping benefits the same, making changes, or waiving all benefits, in order to confirm your choices.',
#  'DEPENDENT INFORMATION - ALL enrollments MUST be complete by 5pm on September 4th.All benefits in this booklet are subject to change.',
#  'DEPENDENT INFORMATION - This is an Employee Benefits Guide and not a contract.',
#  'DEPENDENT INFORMATION - All benefits are subject 1 to the provisions and exclusions of the master contract.',
#  'DEPENDENT INFORMATION - If you intend to elect ANY benefit for your spouse and/or eligible dependents, they must be listed as dependents in the system and you MUST have their SSN to input into the system.',
#  'DEPENDENT INFORMATION - You will not be able to proceed with your enrollment and confirm your elections without inputting the SSN’s for your spouse and/or dependents.',
#  'DEPENDENT INFORMATION - Spouse, Children and Family coverage levels will not be available for you to select if the dependent information is not present.For more information about your Benefits Enrollment please visit: www.explainmybenefits.biz/abc Everyone must complete the online enrollment process, whether you are electing benefits, keeping benefits the same, making changes, or waiving all benefits, in order to confirm your choices.',
#  'DEPENDENT INFORMATION - ALL enrollments MUST be complete by 5pm on September 4th.All benefits in this booklet are subject to change.',
#  'DEPENDENT INFORMATION - This is an Employee Benefits Guide and not a contract.',
#  'DEPENDENT INFORMATION - All benefits are subject 1 to the provisions and exclusions of the master contract.',
#  'BENEFIT ELIGIBILITY - CORE Benefits Plan Coverages at Time of Hire The company’s health insurance plan consists of the following core benefits: Medical Insurance (including prescription drug coverage)',
#  'Basic Life Insurance - Accidental Death and Dismemberment Insurance',
#  'Employee Assistance Program - Medical, dental and vision coverage is offered to all benefit eligible employees as a package, however, you can elect to opt-out of dental and/or vision and remain on the medical plan only (please note that this will not affect your deduction).',
#  'Employee Assistance Program - Electing dependent coverage also entitles your dependent(s) to receive these benefits with the exception of the Basic Life and Accidental Death and Dismemberment Insurance.',
#  'Employee Assistance Program - The employee costs for these Core Benefits are payroll deducted under a pre-payment plan.',
#  'Employee Assistance Program - Deductions are taken the month before the effective date of coverage.',
#  'Employee Assistance Program - For example, if your effective date is December 1st, your payroll deductions would be taken in November.',
#  'Employee Assistance Program - There are 26 deductions per year.Employees will also be offered the following optional benefits that can be elected on a voluntary basis and payroll deducted:',
#  'Flexible Spending Accounts (Medical & Dependent Care) - Supplemental Insurance such as Optional Life, Critical and Accident Insurance, Hospital Indemnity',
#  'Open Enrollment - The company has an Open Enrollment period every year when changes to your benefit elections can be made that will be effective when the new plan year begins on October 1st.',
#  'Open Enrollment - During Open Enrollment, employees may: Change your Section 125 Tax Election Add and/or Remove Dependents Apply for Short Term Disability and/or Long Term Disability Enroll in a Flexible Spending Account During open enrollment, employees may also enroll or cancel the following Optional Plans:',
#  'Transamerica Hospital Indemnity Coverage - Page 19 - \uf0b7 This policy pays a specified amount for each day a covered person is confined to the hospital and provides benefit for a range of other medical situations.',
#  'Transamerica Hospital Indemnity Coverage - Page 19 - Benefit payments go straight to you.Long Term Disability through Disability Carrier - Page 15 \uf0b7 All benefits in this booklet are subject to change.',
#  'Transamerica Hospital Indemnity Coverage - Page 19 - This is an Employee Benefits Guide and not a contract.',
#  'Transamerica Hospital Indemnity Coverage - Page 19 - All benefits are subject to the provisions and exclusions of the master contract.',
#  'Transamerica Hospital Indemnity Coverage - Page 19 - 2',
#  'Transamerica Hospital Indemnity Coverage - Page 19 - \uf0b7 This policy pays a specified amount for each day a covered person is confined to the hospital and provides benefit for a range of other medical situations.',
#  'Transamerica Hospital Indemnity Coverage - Page 19 - Benefit payments go straight to you.Long Term Disability through Disability Carrier - Page 15 \uf0b7 All benefits in this booklet are subject to change.',
#  'Transamerica Hospital Indemnity Coverage - Page 19 - This is an Employee Benefits Guide and not a contract.',
#  'Transamerica Hospital Indemnity Coverage - Page 19 - All benefits are subject to the provisions and exclusions of the master contract.',
#  'Transamerica Hospital Indemnity Coverage - Page 19 - 2',
#  'GROUP INSURANCE ELIGIBILITY - The company’s group insurance plan year is October 1st through September 30th.',
#  'Employee Eligibility - Employees are eligible to participate in the company’s insurance plans if they are full-time employees working a minimum of 30 hours per week.',
#  'Employee Eligibility - Coverage will be effective the 1st of the month following 30 days of employment.For example: If you are hired on February 11th, your coverage will be effective on April 1st.',
#  'Termination - If you separate employment from the company, your insurance will continue through the end of the month in which the separation occurred.',
#  'Dependent Eligibility - A dependent is defined as the legal spouse and dependent child(ren) of the participant or the spouse.',
#  'Dependent Eligibility - Dependent children may be covered through the end of the calendar year in which the child reaches age 30 for medical, dental, and vision (see below for additional information).',
#  'Dependent Eligibility - The term “child” includes any of the following; A natural child A stepchild A legally adopted child A foster child A newborn (up to age 18 moths) of a covered dependent (Florida) A child for whom legal guardianship has been awarded to the participant or the participant’s spouse',
#  'Dependent Eligibility Age Requirements - Over-age Dependents may be covered by the medical, dental, and vision plans through the end of the calendar year in which the child turns age 26.Medical, dental, and vision coverage may continue to the end of the calendar year in which the dependent reaches the age of 30, if the dependent is: Unmarried with no dependents; AND A Florida resident, or full-time or part-time student; AND Otherwise uninsured; AND Not entitled to Medicare benefits under Title XVIII of the Social Security Act, unless the child is handicapped.',
#  'Disabled Dependents - Coverage for an unmarried dependent child may be continued beyond age 26 if: 1.',
#  'Disabled Dependents - The dependent is physically or mentally disabled and incapable of self-sustaining employment; AND 2.',
#  'Disabled Dependents - The dependent is otherwise eligible for coverage under the group medical plan; AND 3.',
#  'Disabled Dependents - The dependent has been continuously insured; AND 4.',
#  'Disabled Dependents - Coverage began prior to the age of 19.Proof of disability will be required upon request.',
#  'Disabled Dependents - Please contact Employee Benefits Coordinator if further clarification is required.Premium for OAD Beginning October 1st of the calendar year in which the child reaches age 27 through the end of the calendar year in which the child reaches age 30, that portion of health insurance premium that is attributable to covering the overage dependent (the “OAD value”) will be deducted on a post tax basis.',
#  'Disabled Dependents - If the OAD value is greater than the payroll deduction, the additional employer subsidized portion of the value (OAD value minus payroll deduction) will be reported as imputed income to the employee and included as income on the W-2.All benefits in this booklet are subject to change.',
#  'Disabled Dependents - This is an Employee Benefits Guide and not a contract.',
#  'Disabled Dependents - All benefits are subject 3 to the provisions and exclusions of the master contract.',
#  'Disabled Dependents - Coverage for an unmarried dependent child may be continued beyond age 26 if: 1.',
#  'Disabled Dependents - The dependent is physically or mentally disabled and incapable of self-sustaining employment; AND 2.',
#  'Disabled Dependents - The dependent is otherwise eligible for coverage under the group medical plan; AND 3.',
#  'Disabled Dependents - The dependent has been continuously insured; AND 4.',
#  'Disabled Dependents - Coverage began prior to the age of 19.Proof of disability will be required upon request.',
#  'Disabled Dependents - Please contact Employee Benefits Coordinator if further clarification is required.Premium for OAD Beginning October 1st of the calendar year in which the child reaches age 27 through the end of the calendar year in which the child reaches age 30, that portion of health insurance premium that is attributable to covering the overage dependent (the “OAD value”) will be deducted on a post tax basis.',
#  'Disabled Dependents - If the OAD value is greater than the payroll deduction, the additional employer subsidized portion of the value (OAD value minus payroll deduction) will be reported as imputed income to the employee and included as income on the W-2.All benefits in this booklet are subject to change.',
#  'Disabled Dependents - This is an Employee Benefits Guide and not a contract.',
#  'Disabled Dependents - All benefits are subject 3 to the provisions and exclusions of the master contract.',
#  'QUALIFYING EVENTS AND IRS CODE SECTION 125 - IRS Code Section 125 Premiums for medical, dental, and vision insurance, and/or certain supplemental policies and contributions to FSA accounts (Health Care and Dependent Care FSAs) are deducted through a Cafeteria Plan established under Section 125 of the Internal Revenue Code (IRC) and are pre-tax to the extent permitted.',
#  'QUALIFYING EVENTS AND IRS CODE SECTION 125 - Under Section 125, changes to your pre-tax benefits can be made ONLY during the Open Enrollment period unless you or your qualified dependents experience a qualifying event and the request to make a change is made within 30 days of the qualifying event.Under certain circumstances, you may be allowed to make changes to your benefits elections during the plan year, if the event affects your own, your spouse’s, or your dependent’s coverage eligibility.',
#  'QUALIFYING EVENTS AND IRS CODE SECTION 125 - An “eligible” qualifying event is determined by the Internal Revenue Service (IRS) Code, Section 125.Examples of Qualifying Events You get married or divorced You have a child, gain legal custody or adopt a child Your spouse and/or other dependent(s) die(s) You, your spouse, or dependent(s) terminate or start employment An increase or decrease in your work hours causes eligibility or ineligibility A covered dependent no longer meets eligibility criteria for coverage A child gains or loses coverage with an ex-spouse Gain or loss of Medicare coverage Losing eligibility for coverage under a State Medicaid or CHIP (including Florida Kid Care) program (60 day notification period).Becoming eligible for State premium assistance under Medicaid or CHIP (60 day notification period).',
#  'Important - If you experience a qualifying event, you must contact the Employee Benefit Coordinator within 30 days of the qualifying event to make the appropriate changes to your coverage.',
#  'Important - Beyond 30 days, requests will be denied and the employee may be responsible both legally and financially for any claim and/or expense incurred as a result of the employee or a dependent who continues to be enrolled but no longer meets eligibility requirements.',
#  'Important - If approved, changes will take place in accordance with the carrier’s policies and procedures.',
#  'Important - However, newborns are effective on the date of birth.',
#  'Important - You may be required to furnish valid documentation supporting a change in status or “Qualifying Event”.All benefits in this booklet are subject to change.',
#  'Important - This is an Employee Benefits Guide and not a contract.',
#  'Important - All benefits are subject to the provisions and exclusions of the master contract.',
#  'Important - 4',
#  'Important - If you experience a qualifying event, you must contact the Employee Benefit Coordinator within 30 days of the qualifying event to make the appropriate changes to your coverage.',
#  'Important - Beyond 30 days, requests will be denied and the employee may be responsible both legally and financially for any claim and/or expense incurred as a result of the employee or a dependent who continues to be enrolled but no longer meets eligibility requirements.',
#  'Important - If approved, changes will take place in accordance with the carrier’s policies and procedures.',
#  'Important - However, newborns are effective on the date of birth.',
#  'Important - You may be required to furnish valid documentation supporting a change in status or “Qualifying Event”.All benefits in this booklet are subject to change.',
#  'Important - This is an Employee Benefits Guide and not a contract.',
#  'Important - All benefits are subject to the provisions and exclusions of the master contract.',
#  'Important - 4',
#  'MEDICAL PREMIUMS - HEALTH CARE COSTS continue to outpace general inflation and are under pressure by fees related to federal health reform, new technology, and late identification of serious medical conditions that require advanced treatments.',
#  'MEDICAL PREMIUMS - This year, premium reductions will be available to further motivate participants to take proactive steps before conditions arise or become serious issues.',
#  'How To Reduce Your Premiums - A new program is being introduced to help you stay healthier and reduce your 2015 medical insurance premiums by 10% or 20%.',
#  'BI-WEEKLY PAYROLL DEDUCTIONS - Tobacco User and No Goals Achieved Coverage Levels HMO Mid HMO High Basic PPO Employee Only $XX.XX $XX.XX $XX.XX Employee & Spouse $XXX.XX $XXX.XX $XXX.XX Employee & Child(ren) $XXX.XX $XXX.XX $XXX.XX Employee & Family $XXX.XX $XXX.XX $XXX.XX One Goal Achieved Tobacco Free or HRA/Biometric Screening Coverage Levels HMO Mid HMO High Basic PPO Employee Only $XX.XX $XX.XX $XX.XX Employee & Spouse $XXX.XX $XXX.XX $XXX.XX Employee & Child(ren) $XXX.XX $XXX.XX $XXX.XX Employee & Family $XXX.XX $XXX.XX $XXX.XX New for 2015/2016 Two Goals Achieved Tobacco Free and HRA/Biometric Screening Coverage Levels HMO Mid HMO High Basic PPO Employee Only $X.XX $XX.XX $X.XX Employee & Spouse $XXX.XX $XXX.XX $XXX.XX Employee & Child(ren) $XXX.XX $XXX.XX $XXX.XX Employee & Family $XXX.XX $XXX.XX $XXX.XX 5 All benefits in this booklet are subject to change.',
#  'BI-WEEKLY PAYROLL DEDUCTIONS - This is an Employee Benefits Guide and not a contract.',
#  'BI-WEEKLY PAYROLL DEDUCTIONS - All benefits are subject to the provisions and exclusions of the master contract.',
#  'BI-WEEKLY PAYROLL DEDUCTIONS - Tobacco User and No Goals Achieved Coverage Levels HMO Mid HMO High Basic PPO Employee Only $XX.XX $XX.XX $XX.XX Employee & Spouse $XXX.XX $XXX.XX $XXX.XX Employee & Child(ren) $XXX.XX $XXX.XX $XXX.XX Employee & Family $XXX.XX $XXX.XX $XXX.XX One Goal Achieved Tobacco Free or HRA/Biometric Screening Coverage Levels HMO Mid HMO High Basic PPO Employee Only $XX.XX $XX.XX $XX.XX Employee & Spouse $XXX.XX $XXX.XX $XXX.XX Employee & Child(ren) $XXX.XX $XXX.XX $XXX.XX Employee & Family $XXX.XX $XXX.XX $XXX.XX New for 2015/2016 Two Goals Achieved Tobacco Free and HRA/Biometric Screening Coverage Levels HMO Mid HMO High Basic PPO Employee Only $X.XX $XX.XX $X.XX Employee & Spouse $XXX.XX $XXX.XX $XXX.XX Employee & Child(ren) $XXX.XX $XXX.XX $XXX.XX Employee & Family $XXX.XX $XXX.XX $XXX.XX 5 All benefits in this booklet are subject to change.',
#  'BI-WEEKLY PAYROLL DEDUCTIONS - This is an Employee Benefits Guide and not a contract.',
#  'BI-WEEKLY PAYROLL DEDUCTIONS - All benefits are subject to the provisions and exclusions of the master contract.',
#  'New Medical Plan Premium Reductions - Non-Smokers get 90% of the Smokers actively trying to quit get Non-Smokers get 100% of the Employee premium for the Basic (PPO) 90% of the Employee premium for Employee premium for the Basic plan paid by the company.',
#  'New Medical Plan Premium Reductions - the Basic (PPO) plan paid by the (PPO) plan paid by the company if company if they complete the Health they complete the Health Risk Risk Assessment and get a Biometric Assessment and get a Biometric',
#  'Screening. Screening - HMO Mid HMO High Basic PPO',
#  'Plans - In Network Only In Network Only In Network Out of Network',
#  'Coinsurance 0% 20% 20% 40% - Out of Pocket Maximum (Includes Deductible, Coinsurance, Copay, Rx)',
#  'Office Visit - Birth through age 15 C o v e r e d 1 00% Covered 100% Covered 100% 40% Coinsurance Ages 16 and older Ded + 40% Lab, X-ray, other preventive tests 40% Coinsurance',
#  'Covered 100% Covered 100% Covered 100% - Birth through age 15 Ded + 40% Ages 16 and older',
#  'Physician Office Visit Sickness & Injury - Primary Care $30 Co-pay $30 Co-pay $25 Co-pay Ded + 40% Specialist $70 Co-pay $70 Co-pay $50 Co-pay Ded + 40% Lab / X-rays Physician’s Office $30 PCP/$70 Specialist $ 2 5 P C P / $ 5 0 S pecialist D e d + 40%',
#  'Covered 100% - Independent Lab Ded + 20% D e d + 20% D e d + 4 0 %',
#  'Advanced Radiology Imaging - Physician’s Office C o v ered 100% C o v e red 100% C o v ered 100% D e d + 40%',
#  'Hospital Services, Urgent Care - In-Patient Hospital Services Deductible Ded + 20% Ded + 20% $300 PAD + Ded + 40%',
#  'Outpatient Surgery Deductible Ded + 20% Ded + 20% Ded + 40% - Emergency Room $300 Co-pay $300 Co-pay $300 Co-pay $300 Co-pay + Ded Urgent Care $50 Co-pay $50 Co-pay $50 Co-pay $20 Co-pay + Ded How to Locate A Provider - To search for a participating provider, go to www.medical.com, select “Find a Doctor”, then click on “Select a Plan of your Search” and choose “Open Access Plus Network”.',
#  'Outpatient Surgery Deductible Ded + 20% Ded + 20% Ded + 40% - Fill in the rest of the search criteria and click “Search”.All benefits in this booklet are subject to change.',
#  'Outpatient Surgery Deductible Ded + 20% Ded + 20% Ded + 40% - This is an Employee Benefits Guide and not a contract.',
#  'Outpatient Surgery Deductible Ded + 20% Ded + 20% Ded + 40% - All benefits are subject to the provisions and exclusions of the master contract.',
#  'Outpatient Surgery Deductible Ded + 20% Ded + 20% Ded + 40% - 6',
#  'Outpatient Surgery Deductible Ded + 20% Ded + 20% Ded + 40% - Emergency Room $300 Co-pay $300 Co-pay $300 Co-pay $300 Co-pay + Ded Urgent Care $50 Co-pay $50 Co-pay $50 Co-pay $20 Co-pay + Ded How to Locate A Provider - To search for a participating provider, go to www.medical.com, select “Find a Doctor”, then click on “Select a Plan of your Search” and choose “Open Access Plus Network”.',
#  'Outpatient Surgery Deductible Ded + 20% Ded + 20% Ded + 40% - Fill in the rest of the search criteria and click “Search”.All benefits in this booklet are subject to change.',
#  'Outpatient Surgery Deductible Ded + 20% Ded + 20% Ded + 40% - This is an Employee Benefits Guide and not a contract.',
#  'Outpatient Surgery Deductible Ded + 20% Ded + 20% Ded + 40% - All benefits are subject to the provisions and exclusions of the master contract.',
#  'Outpatient Surgery Deductible Ded + 20% Ded + 20% Ded + 40% - 6',
#  'OTHER AVAILABLE PLAN RESOURCES - Medical offers all enrolled members and dependents additional services and discounts through value added programs.',
#  'OTHER AVAILABLE PLAN RESOURCES - For more details regarding other available plan resources, please refer to your Summary of Benefits and Coverage (SBC).24 Hour Help Information Hotline (800) MEDICAL-24 The Medical 24-Hour Health Information Line provides you access to helpful, reliable information and assistance from qualified health information nurses on a wide range of health topics 24 hours a day, any day of the year.',
#  'OTHER AVAILABLE PLAN RESOURCES - Not sure what to do when your child has a fever in the middle of the night?',
#  'OTHER AVAILABLE PLAN RESOURCES - Have you injured yourself and are not sure if you should seek treatment or go see a doctor?',
#  'OTHER AVAILABLE PLAN RESOURCES - There are over 1,000 topics in the Health Information Library that include FREE audio, video and printed information on aging, women’s health, nutrition, surgery and specific medical conditions to help you weigh the risks and advantages of treatment options.',
#  'OTHER AVAILABLE PLAN RESOURCES - The call is FREE and strictly confidential.',
#  'Healthy Rewards - Medical’s Healthy Rewards is provided to you automatically at no additional cost and offers access to discounted health and wellness programs at participating providers.',
#  'Healthy Rewards - Members can log on to www.mymedical.com and select Healthy Rewards to learn more about these programs or call (800) 870- 3470.',
#  'Alternative Medicine - The myMedical Mobile App The myMedical Mobile App gives you an easy way to organize and access your important health information.Anytime.',
#  'Alternative Medicine - Anywhere.',
#  'Alternative Medicine - Download it today from the App StoreSM or Google Play™.',
#  'Alternative Medicine - With the myMedical Mobile App you can: Find a doctor, dentist or health care facility Access maps for instant driving directions View ID cards for the entire family Review deductibles, account balances and claims Compare prescription drug costs Speed-dial Medical Home Delivery Pharmacy™ Store and organize all important contact info for doctors, hospitals and pharmacies Add health care professionals to contact list right from a claim or directory search And, much more!7 All benefits in this booklet are subject to change.',
#  'Alternative Medicine - This is an Employee Benefits Guide and not a contract.',
#  'Alternative Medicine - All benefits are subject to the provisions and exclusions of the master contract.',
#  'Alternative Medicine - The myMedical Mobile App The myMedical Mobile App gives you an easy way to organize and access your important health information.Anytime.',
#  'Alternative Medicine - Anywhere.',
#  'Alternative Medicine - Download it today from the App StoreSM or Google Play™.',
#  'Alternative Medicine - With the myMedical Mobile App you can: Find a doctor, dentist or health care facility Access maps for instant driving directions View ID cards for the entire family Review deductibles, account balances and claims Compare prescription drug costs Speed-dial Medical Home Delivery Pharmacy™ Store and organize all important contact info for doctors, hospitals and pharmacies Add health care professionals to contact list right from a claim or directory search And, much more!7 All benefits in this booklet are subject to change.',
#  'Alternative Medicine - This is an Employee Benefits Guide and not a contract.',
#  'Alternative Medicine - All benefits are subject to the provisions and exclusions of the master contract.',
#  'Benefits Tip - Local retail network pharmacies may provide free antibiotics, diabetes and blood pressure medications and $4 generic',
#  'Prescription Coverage - prescriptions.',
#  'Prescription Coverage - Take advantage of these programs to keep your costs down.',
#  'Prescription Coverage - HMO Mid HMO High Basic PPO In Network Only In Network Only In Network Out of Network',
#  'Non-Preferred $50 Copay $50 Copay $50 Copay - Mail Order (90 days)',
#  'Non-Preferred $100 Copay $100 Copay $90 Copay - Select Publix supermarket pharmacies offer some prescriptions for free, including certain antibiotics such as amlodipine, metformin and',
#  'Lisinopril. - Where can I find free or nearly free antibiotics?Target, Sam’s Club and Walmart offer 30-day supplies of some generic drugs for $4 and a 90-day supply for $10.All benefits in this booklet are subject to change.',
#  'Lisinopril. - This is an Employee Benefits Guide and not a contract.',
#  'Lisinopril. - All benefits are subject to the provisions and exclusions of the master contract.',
#  'Lisinopril. - 8',
#  'Lisinopril. - Where can I find free or nearly free antibiotics?Target, Sam’s Club and Walmart offer 30-day supplies of some generic drugs for $4 and a 90-day supply for $10.All benefits in this booklet are subject to change.',
#  'Lisinopril. - This is an Employee Benefits Guide and not a contract.',
#  'Lisinopril. - All benefits are subject to the provisions and exclusions of the master contract.',
#  'Lisinopril. - 8',
#  'Dental - The Dental PPO plan is “open access” and allows you to receive services from any dental provider with out selecting a Primary Dental Provider (PDP) and does not require referrals to specialists.',
#  'Dental - The PPO plan provides benefits for services received from in-network and out-of-network providers.',
#  'Plan Dental - In Network Out of Network',
#  'Preventative Services - Plan pays 100% Deductible is waived.Exams, Cleanings, X-Rays, etc.',
#  'Basic Services - Fillings, Simple extractions, Periodontics, Root Canals, 10% 20% etc.',
#  'Major Services - 40% 50% Crowns, Dentures, Bridges, Implants, etc.',
#  'Orthodontics - $1,500 Lifetime Maximum for child(ren) under age 19 50% 50% Deductible does not apply to Orthodontic services.Employee Only $X.XX',
#  'BI-WEEKLY DEDUCTIONS - Employee & Spouse $X.XX Employee & Children $XX.XX Family $XX.XX Need to find an In',
#  'Network Dentist ? - To search for a participating provider, You can increase your plan year go to www.dental.com, select “Find a maximum by $100 annually if Doctor”, then click on “Select a Plan you receive preventive services for your Search” and choose “Dental PPO” then “Radius Network”.',
#  'Network Dentist ? - Fill in during the prior plan year.the rest of your search criteria and click Search.9 All benefits in this booklet are subject to change.',
#  'Network Dentist ? - This is an Employee Benefits Guide and not a contract.',
#  'Network Dentist ? - All benefits are subject to the provisions and exclusions of the master contract.',
#  'Network Dentist ? - To search for a participating provider, You can increase your plan year go to www.dental.com, select “Find a maximum by $100 annually if Doctor”, then click on “Select a Plan you receive preventive services for your Search” and choose “Dental PPO” then “Radius Network”.',
#  'Network Dentist ? - Fill in during the prior plan year.the rest of your search criteria and click Search.9 All benefits in this booklet are subject to change.',
#  'Network Dentist ? - This is an Employee Benefits Guide and not a contract.',
#  'Network Dentist ? - All benefits are subject to the provisions and exclusions of the master contract.',
#  'Vision - Vision Carrier is the company’s carrier again this year.',
#  'Vision - Your vision is important to your health.',
#  'Vision - Whether you have 20/20 or less than perfect vision, everyone needs to receive regular vision care.',
#  'Vision - Don’t take chances with your vision; take advantage of this important benefit.Out-of-Network',
#  'Reimbursement - Exam (every 12 months) $5 Copay $18',
#  'Exam Options: - Standard Contact Lens Fit & Follow-up Up to $40 N / A Premium Contact Lens Fit & Follow-up 10% off Retail Price N/A Frames: (every 12 months) $ 0 C o p a y ; $ 1 1 0 A l l o w ance $55 Any available frame at provider location 20% off balance over $110 Standard Plastic Lenses: (every 12 months) Single Vision / Bifocal / Trifocal $ 1 0 C o p a y $ 1 3 / $ 2 3 / $ 4 0',
#  'Standard Progressive Lenses $70 Copay $ 2 5 - Premium Progressive Lenses $70 Copay, 80% of Charge less $120 Allowance $25',
#  'Lens Options: - UV Treatment $12 Copay $ 2 Tint (Solid and Gradient) $12 Copay $ 2',
#  'Standard Polycarbonate - Adult $35 Copay $ 3 - Standard Polycarbonate - Kids under 19 $ 35 Copay $ 3',
#  'Standard Anti-Reflective Coating $40 Copay $ 2 3 - Polarized & Other Add-Ons 20% off Retail Price N/A Other Add-Ons 20% off Retail Price N/A',
#  'Contact Lenses - (Contact lens allowance includes materials only) Conventional $0 Copay; $120 allowance, 15% off balance over $120 $ 9 6 Disposable $0 Copy; $120 allowance, plus balance over $120 $ 9 6 Medically Necessary $0 Copay; Paid-in-Full $200 Lasik or PRK from U.S.',
#  'Contact Lenses - Laser Network 15% off Retail or 5% off promotional N/A Employee Only $X.XX',
#  'BI-WEEKLY DEDUCTIONS - *Family $X.XX',
#  'Additional Discount - Members can receive up to a 20% How do you discount on items not covered by To search for a participating provider, locate a the plan at network providers.',
#  'Additional Discount - For go to www.vision.com, select “Find a provider?more information, please visit the Provider”, enter your Zip Code and Vision website or contact choose “Select” network and click Get customer service at 866-723-0513.',
#  'Additional Discount - Results.All benefits in this booklet are subject to change.',
#  'Additional Discount - This is an Employee Benefits Guide and not a contract.',
#  'Additional Discount - All benefits are subject to the provisions and exclusions of the master contract.',
#  'Additional Discount - 10',
#  'Additional Discount - Members can receive up to a 20% How do you discount on items not covered by To search for a participating provider, locate a the plan at network providers.',
#  'Additional Discount - For go to www.vision.com, select “Find a provider?more information, please visit the Provider”, enter your Zip Code and Vision website or contact choose “Select” network and click Get customer service at 866-723-0513.',
#  'Additional Discount - Results.All benefits in this booklet are subject to change.',
#  'Additional Discount - This is an Employee Benefits Guide and not a contract.',
#  'Additional Discount - All benefits are subject to the provisions and exclusions of the master contract.',
#  'Additional Discount - 10',
#  'Flexible Spending Account - The Company offers Flexible Spending Accounts (FSA).The FSA Plan Year is October 1, 2015 through September Medical Flexible 30, 2016.',
#  'Flexible Spending Account - You may elect to participate in either FSA or Spending Accounts will both simultaneously.be capped at $2,500.If you have predictable medical expenses for yourself you’re your family, such as deductibles and copays, or any work-related day care expenses, FSAs may be right for you.',
#  'Flexible Spending Account - FSAs allow you to set aside money for',
#  'MEDICAL FLEXIBLE SPENDING ACCOUNT - reimbursement of healthcare and day care expenses you regularly pay.',
#  'MEDICAL FLEXIBLE SPENDING ACCOUNT - The amount you set aside is not taxed and This money will not be taxable income to you is automatically deducted from your paycheck and ad can be used to offset the cost of a wide deposited into the FSA.',
#  'MEDICAL FLEXIBLE SPENDING ACCOUNT - During the year, you have access variety of eligible medical expenses that to this account for reimbursement of some expenses that generate out-of-pocket costs for you or your are not covered by insurance.',
#  'MEDICAL FLEXIBLE SPENDING ACCOUNT - An FSA not only results in a qualified dependents.',
#  'MEDICAL FLEXIBLE SPENDING ACCOUNT - Employees can also substantial tax savings, it also increases your spending receive reimbursement for expenses related to power.',
#  'MEDICAL FLEXIBLE SPENDING ACCOUNT - There are two types of FSAs: dental and vision care (that are not classified as cosmetic).',
#  'MEDICAL FLEXIBLE SPENDING ACCOUNT - Note: The entire Health Care FSA DEPENDENT CARE election is available to you on the first day This account allows you to set aside up to an annual coverage is effective.maximum of $5,000 if you are a single or married and file a joint tax return ($2,550 if you are married and file A sample list of qualified expenses eligible for a separate tax return) for work-related day care reimbursement include, but are not limited to: expenses.',
#  'MEDICAL FLEXIBLE SPENDING ACCOUNT - Qualified expenses include adult and child day care centers, preschool, and before/after school care for \uf0b7 Ambulance service eligible children and adults.',
#  'MEDICAL FLEXIBLE SPENDING ACCOUNT - \uf0b7 Chiropractic care \uf0b7 Dental fees/Orthodontic fees Please note that if your family’s annual income is over \uf0b7 Diagnostic tests/Health screenings $20,000, this reimbursement option will most likely save \uf0b7 Doctors fees you more money than the dependent care tax credit you \uf0b7 Drug addiction/Alcoholism treatment take on your tax return.',
#  'MEDICAL FLEXIBLE SPENDING ACCOUNT - To qualify, your dependent must \uf0b7 Experimental medical treatment be: \uf0b7 Eyeglasses/Contact lenses (corrective) A child under the age of 13, or \uf0b7 Hearing aids and exams A child, spouse or other dependent that is physical \uf0b7 Injections & vaccinations or mentally incapable of self-care and spends at \uf0b7 Lasik surgery least 8 hours a day in your household.',
#  'MEDICAL FLEXIBLE SPENDING ACCOUNT - \uf0b7 Mental healthcare',
#  '\uf0b7 Nursing Services - Note: Unlike the Healthcare FSA, you will only be \uf0b7 Optometrist fees reimbursed up to the amount that has been deducted \uf0b7 Physician office visits from your paycheck for Dependent Care expenses.',
#  '\uf0b7 Nursing Services - \uf0b7 Prescription drugs',
#  '\uf0b7 Wheelchairs - 11 All benefits in this booklet are subject to change.',
#  '\uf0b7 Wheelchairs - This is an Employee Benefits Guide and not a contract.',
#  '\uf0b7 Wheelchairs - All benefits are subject to the provisions and exclusions of the master contract.',
#  '\uf0b7 Wheelchairs - 11 All benefits in this booklet are subject to change.',
#  '\uf0b7 Wheelchairs - This is an Employee Benefits Guide and not a contract.',
#  '\uf0b7 Wheelchairs - All benefits are subject to the provisions and exclusions of the master contract.',
#  'FLEXIBLE SPENDING ACCOUNTS - Login Information for TASC 1.',
#  'FLEXIBLE SPENDING ACCOUNTS - Login to your account.',
#  'FLEXIBLE SPENDING ACCOUNTS - Go to the MyFSA website at www.fsa.com 2.',
#  'FLEXIBLE SPENDING ACCOUNTS - Enter your 12 Digit ID Username.',
#  'FLEXIBLE SPENDING ACCOUNTS - This can be found on your blue FSA Card.',
#  'FLEXIBLE SPENDING ACCOUNTS - Once logged in you can create your own Username.FSA Guidelines 3.',
#  'FLEXIBLE SPENDING ACCOUNTS - Enter your password.\uf0b7 You can enroll in either or 4.',
#  'FLEXIBLE SPENDING ACCOUNTS - If you are a New User or did not receive your Welcome Kit, click on New both FSAs during open User.enrollment period, new Once you login, you can: hire eligibility, or a 1.',
#  'FLEXIBLE SPENDING ACCOUNTS - Manage your Profile qualifying event only.',
#  'FLEXIBLE SPENDING ACCOUNTS - 2.',
#  'FLEXIBLE SPENDING ACCOUNTS - Manage your Account',
#  '3. Request Reimbursement - \uf0b7 You cannot transfer',
#  '4. Download Reimbursement Request Form - money between FSAs.Requests for Reimbursement \uf0b7 You cannot pay a When paying for an eligible expense, simply swipe your FSA Card at the point- dependent care expense of-purchase.',
#  '4. Download Reimbursement Request Form - If you pay for an expense without your FSA Card, simply submit a from your Health Care Request for Reimbursement via the onling MyFSA Mobile App or Request for FSA or vice versa.',
#  '4. Download Reimbursement Request Form - Reimbursement Wizard in MyFSA, or fax or mail your personalized Request for Reimbursement form with substantiation to FSA.\uf0b7 You cannot deduct reimbursed expenses for FSA Card income tax purposes.',
#  '4. Download Reimbursement Request Form - The FSA Card provides a convenient method to pay for eligible healthcare and dependent care.',
#  '4. Download Reimbursement Request Form - MyBenefits is funded through equal pre-tax payroll \uf0b7 You cannot be deductions based on your annual benefit election.reimbursed for a service Card purchases are limited to your Plan type, and also to merchants with an which you have not inventory information approval system in place to identify FSA-eligible received.purchases.',
#  '4. Download Reimbursement Request Form - Qualifying merchants may include doctors, dentists, vision care \uf0b7 You cannot receive facilities, and day care centers.',
#  '4. Download Reimbursement Request Form - Simply swipe your card at the time you incur the eligible expense and the IIAS automatically approves the purchase of insurance benefits or any eligible items and deducts the amount from your MyBenefits account.other compensation for expenses which are Spend your MyCash funds any way and anywhere you want!',
#  '4. Download Reimbursement Request Form - Visit the MyCash reimbursed through your Manager within MyFSA (www.fsa.com) to view account activity, request an FSAs.',
#  '4. Download Reimbursement Request Form - ATM PIN, make and manage transfers, view and manage multiple bank ac- counts, and more.\uf0b7 Domestic partners are MYWay not eligible as federal \uf0b7 Access to two accounts on one card makes the FSA Card more versatile law does not recognize than ever!them as a qualified \uf0b7 Avoid embarrassing declines.',
#  '4. Download Reimbursement Request Form - MyCash funds can be used to pay for eligible dependent.expenses if no funds are available in your MyBenefits account.\uf0b7 Combine general retail items with healthcare expenses in one transaction.The TASC Card is smart enough to know that eligible expenses are deducted from your MyBenefits account while ineligible expenses are withdrawn from MyCash.\uf0b7 Transfer MyCash funds via a quick, one-time, recurring, or automatic transfer from MyCash manager within MyFSA.',
#  'KNOW THE RULES - All benefits in this booklet are subject to change.',
#  'KNOW THE RULES - This is an Employee Benefits Guide and not a contract.',
#  'KNOW THE RULES - All benefits are subject to the provisions and exclusions of the master contract.',
#  'KNOW THE RULES - 12',
#  'KNOW THE RULES - All benefits in this booklet are subject to change.',
#  'KNOW THE RULES - This is an Employee Benefits Guide and not a contract.',
#  'KNOW THE RULES - All benefits are subject to the provisions and exclusions of the master contract.',
#  'KNOW THE RULES - 12',
#  'BASIC TERM LIFE AND AD&D - The company provides Basic Life and AD&D Insurance through Life Carrier for all eligible employees at no cost to the employee.',
#  'For You For Your Spouse For Your Children - 1x annual salary, up to a',
#  'Company Paid Coverage N/A N/A - maximum of $75,000 Up to maximum of Up to a maximum of',
#  'Additional Amount You - $500,000 (not to exceed $250,000 (not to exceed 50% $5,000 or $10,000',
#  'May Purchase - 5x annual salary) of employee life amount) $.35 per pay or What it will cost you See Rate Chart Below See Rate Chart Below $.69 per pay Dependent Only Life N/A $5,000 or $10,000 $2,000 or $5,000 $.48 per pay or I n c luded in What it will cost you N/A $1.03 per pay Spouse Rate If coverage was not applied for at initial eligibility (or if an upgrade in coverage is requested at a late date) “Evidence of Insurability” must be provided, including health questions.',
#  'Age Age - Rate per $1,000 Rate per $1,000 Rate per $1,000 Rate per $1,000 <20 - 29 $.06 $.03 55 - 59 $.97 $.94 30 - 34 $.12 $.09 60 - 64 $1.42 $1.90 35 - 39 $.16 $.13 65 - 69 $2.31 $2.28 40 - 44 $.21 $.18 70 - 74 $4.27 $4.24 45 - 49 $.31 $.28 75 - 100 $14.17 $14.14 50 - 54 $.52 $.49 *Rates are based on Employee Age for Employee coverage and Spouse Age for Spouse coverage',
#  'Example: - A 36 year old female, Sally, wants to purchase $50,000 of term life insurance..16 x 50 = $8.00 x 12 / 26 = $3.69 Monthly rate per $1,000 # of units/$1,000 monthly premium payroll deduction Always remember to keep your beneficiary forms updated.',
#  'Example: - Beneficiary information may be updated at any time through the Explain My Benefit portal.All benefits in this booklet are subject to change.',
#  'Example: - This is an Employee Benefits Guide and not a contract.',
#  'Example: - All benefits are subject 13 to the provisions and exclusions of the master contract.',
#  'Example: - A 36 year old female, Sally, wants to purchase $50,000 of term life insurance..16 x 50 = $8.00 x 12 / 26 = $3.69 Monthly rate per $1,000 # of units/$1,000 monthly premium payroll deduction Always remember to keep your beneficiary forms updated.',
#  'Example: - Beneficiary information may be updated at any time through the Explain My Benefit portal.All benefits in this booklet are subject to change.',
#  'Example: - This is an Employee Benefits Guide and not a contract.',
#  'Example: - All benefits are subject 13 to the provisions and exclusions of the master contract.',
#  'DISABILITY - A disability can have significant financial impact on a family.',
#  'DISABILITY - Not only does the income from the disabled person stop, but expenses usually increase because of necessary medical and rehabilitation costs.',
#  'DISABILITY - The Company’s disability coverage provides you with a source of income if you are unable to work because of a non-work related short or long-term illness or injury.',
#  'SHORT TERM DISABILITY - The Company provides Basic Short Term Disability (STD) insurance to all eligible employees, at no cost to you.',
#  'SHORT TERM DISABILITY - Employees will be automatically enrolled in Basic STD.The Company also offers a STD Buy-up plan that you can elect to \uf0b7 STD coverage supplements purchase that would reduce your elimination period from 30 days to your lost wages should 7 days.',
#  'SHORT TERM DISABILITY - you be unable to work due to a covered illness, injury or pregnancy.',
# ...
#  'Guaranteed Issue - Each covered person will get one immunization or one screening test per calendar year.',
#  'Guaranteed Issue - (60 day waiting period for this benefit) Examples of Health Screenings \uf0b7 Low dose mammography \uf0b7 Serum cholesterol \uf0b7 Stress Test \uf0b7 Bone Marrow \uf0b7 Pap smear \uf0b7 PSA Test \uf0b7 Colonoscopy \uf0b7 Chest X-ray Also included is a Double Benefit Option that provides a second cash payment in the event a covered person is diagnosed with a different condition or illness.',
#  'Guaranteed Issue - Pays an additional 100% of the original benefit.',
#  'Rates - This benefit is customized by each employee so rates vary, but can start as little as a few dollars a week.All benefits in this booklet are subject to change.',
#  'Rates - This is an Employee Benefits Guide and not a contract.',
#  'Rates - All benefits are subject to the provisions and exclusions of the master contract.',
#  'Rates - 20',
#  'Rates - This benefit is customized by each employee so rates vary, but can start as little as a few dollars a week.All benefits in this booklet are subject to change.',
#  'Rates - This is an Employee Benefits Guide and not a contract.',
#  'Rates - All benefits are subject to the provisions and exclusions of the master contract.',
#  'Rates - 20',
#  'VOLUNTARY BENEFITS - Universal Life with Long Term Care Universal Life with Long Term Care includes both a death benefit and a living benefit.\uf0b7 Trustmark Universal Life with Long Term Care is a permanent life insurance that is designed to match your needs throughout your lifetime.',
#  'VOLUNTARY BENEFITS - It pays a higher death benefit during your working years when expenses are Special Underwriting at Initial Offering high and you need maximum protection.',
#  'Guaranteed Issue (Employee Only) - \uf0b7 The Universal Life with Long Term Care is priced to remain the same cost to you until age 100.',
#  'Guaranteed Issue (Employee Only) - The lesser of the face amount purchased by $16 per week or \uf0b7 The death benefit reduces at age 70 when the need for $200,000 life insurance typically decreases.\uf0b7 The Living Benefit, Long Term Care never reduces and is 4% of the original death benefit per month for up to 25 months.\uf0b7 If you use the Long Term Care benefit, your death benefit amount does not reduce due to the Benefit Restoration feature included.\uf0b7 Coverage available for spouse and children as well.LifeEvents® with Long Term Care example: $100,000 Death Benefit',
#  'Maximum Benefit Amount - Long Term Care Benefit (LTC): Before Age 70 After Age 70 Pays a monthly benefit equal to 4% of your death benefit $100,000 $100,000 for up to 25 months.',
#  'Benefit Restoration: $100,000 $33,333 - Restores the death benefit that is reduced to pay for LTC.',
#  'Total Maximum Benefit: $200,000 $133,333 - Long Term Care Benefits may double the value of your insurance.',
#  'Rates - This benefit is customized by each employee so rates vary, but can start as little as a few dollars a week.All benefits in this booklet are subject to change.',
#  'Rates - This is an Employee Benefits Guide and not a contract.',
#  'Rates - All benefits are subject 21 to the provisions and exclusions of the master contract.',
#  'Rates - This benefit is customized by each employee so rates vary, but can start as little as a few dollars a week.All benefits in this booklet are subject to change.',
#  'Rates - This is an Employee Benefits Guide and not a contract.',
#  'Rates - All benefits are subject 21 to the provisions and exclusions of the master contract.',
#  'IDENTITY THEFT - LifeLock Identity Theft Protection Identity theft in the United States is a major problem that continues to be on the rise.',
#  'IDENTITY THEFT - Professional protection and assistance have become important tools in fighting the identity theft epidemic.Thieves today can get a hold of your personal information from trash cans, dumpsters, stolen mail, and even shoulder surfing.',
#  'IDENTITY THEFT - Once thieves have your information, it’s a simple matter to open new fraudulent accounts and make purchases in your name.When you enroll in LifeLock, you can be confident knowing that they are available 24 hours a day, 7 days a week, and committed 100% to helping protect your information as if it were their own.LifeLock offers Proactive Protection: Did you know?\uf0b7 LifeLock Identity Alert System \uf0b7 eRecon \uf0b7 TrueAddress \uf0b7 WalletLock LifeLock provides a $1 Million Total \uf0b7 Reduction in Pre-Approved Credit Card offers Service Guarantee',
#  '\uf0b7 Free Annual Credit Reports - LifeLock’s proactive approach works to',
#  '\uf0b7 24-Hour Customer Service - help stop identity theft before it hap- pens.',
#  '\uf0b7 24-Hour Customer Service - As a LifeLock member, if you become a victim of identity theft because of a failure in their service, they will help fix it at their expense, up to $1,000,000.Employee Only $X.XX BI-WEEKLY DEDUCTIONS Employee & Spouse $X.XX *Employee & *Children $X.XX *Family $XX.XX *Employee & Children and Family Tiers: You may enroll up to 8 children with 4 of those children between the ages of 18 and 26.All benefits in this booklet are subject to change.',
#  '\uf0b7 24-Hour Customer Service - This is an Employee Benefits Guide and not a contract.',
#  '\uf0b7 24-Hour Customer Service - All benefits are subject to the provisions and exclusions of the master contract.',
#  '\uf0b7 24-Hour Customer Service - 22',
#  '\uf0b7 24-Hour Customer Service - help stop identity theft before it hap- pens.',
#  '\uf0b7 24-Hour Customer Service - As a LifeLock member, if you become a victim of identity theft because of a failure in their service, they will help fix it at their expense, up to $1,000,000.Employee Only $X.XX BI-WEEKLY DEDUCTIONS Employee & Spouse $X.XX *Employee & *Children $X.XX *Family $XX.XX *Employee & Children and Family Tiers: You may enroll up to 8 children with 4 of those children between the ages of 18 and 26.All benefits in this booklet are subject to change.',
#  '\uf0b7 24-Hour Customer Service - This is an Employee Benefits Guide and not a contract.',
#  '\uf0b7 24-Hour Customer Service - All benefits are subject to the provisions and exclusions of the master contract.',
#  '\uf0b7 24-Hour Customer Service - 22',
#  'Veterinary Pet Insurance - ® the #1 choice in America for pet insurance Voluntary Benefit - Will not be payroll deducted Major Medical Plan Medical Plan Optional routine care coverage is available to',
#  'Comprehensive™ Economical™ - complement any VPI® \uf09f Coverage for ongoing conditions \uf09f Coverage for ongoing conditions plan for as little as \uf09f Freedom to use any vet, anywhere \uf09f Freedom to use any vet, anywhere $12/month, with \uf09f Benefits renew in full each year \uf09f Benefits renew in full each year benefits for wellness + Double the benefit allowances of exams, vaccinations and the Medical Plan much more.+ Limited hereditary coverage after Injury, Feline Select® and the first year Avian & Exotic plans are $24 - 34 /month† $18 - 26 /month† also available.vomiting bladder infection lymph node cancer cruciate rupture - sample (gastritis) (cystitis) (lymphosarcoma) surgical repair',
#  'Major Medical Plan - veterinary fee veterinary fee veterinary fee veterinary fee reimbursements* $1,055 $767 $4,320 $3,697 reimbursement reimbursement reimbursement reimbursement $860 $667 $3,230 $3,290 \uf06c Ear infections \uf06c Vomiting \uf06c Leukemia what’s \uf06c Skin rashes \uf06c Cancer \uf06c Abscesses covered?',
#  'Major Medical Plan - \uf06c Accidents, including lacerations, \uf06c Diabetes \uf06c Respiratory problems poisonings, fractures, sprains, \uf06c Kidney and bladder infections \uf06c And more and wounds how does Visit Submit Receive 1.',
#  'Major Medical Plan - 2.',
#  'Major Medical Plan - 3.VPI work?',
#  'Major Medical Plan - Any vet.',
#  'Major Medical Plan - A claim.',
#  'Major Medical Plan - Reimbursement.*These are actual claims from VPI policyholders who were enrolled prior to the introduction of the VPI Major Medical Plan and VPI Medical Plan.',
#  'Major Medical Plan - Claims were reimbursed according to the respective plan in which the policyholder was enrolled at the time.',
#  'Major Medical Plan - Amounts shown here reflect what would have been reimbursed through the updated plans based on a $100 annual deductible.',
#  'Major Medical Plan - Available deductible amounts are $100, $250, $500 and $1,000.** rate discounts apply to the base medical plan only.† Premiums vary based on the age of the pet, species, size (as an adult), plan type, deductible and state of residence.Get your discount today** 877-PETS-VPI \uf09f www.petinsurance.com/abc All benefits in this booklet are subject to change.',
#  'Major Medical Plan - This is an Employee Benefits Guide and not a contract.',
#  'Major Medical Plan - All benefits are subject 23 to the provisions and exclusions of the master contract.',
#  'Major Medical Plan - veterinary fee veterinary fee veterinary fee veterinary fee reimbursements* $1,055 $767 $4,320 $3,697 reimbursement reimbursement reimbursement reimbursement $860 $667 $3,230 $3,290 \uf06c Ear infections \uf06c Vomiting \uf06c Leukemia what’s \uf06c Skin rashes \uf06c Cancer \uf06c Abscesses covered?',
#  'Major Medical Plan - \uf06c Accidents, including lacerations, \uf06c Diabetes \uf06c Respiratory problems poisonings, fractures, sprains, \uf06c Kidney and bladder infections \uf06c And more and wounds how does Visit Submit Receive 1.',
#  'Major Medical Plan - 2.',
#  'Major Medical Plan - 3.VPI work?',
#  'Major Medical Plan - Any vet.',
#  'Major Medical Plan - A claim.',
#  'Major Medical Plan - Reimbursement.*These are actual claims from VPI policyholders who were enrolled prior to the introduction of the VPI Major Medical Plan and VPI Medical Plan.',
#  'Major Medical Plan - Claims were reimbursed according to the respective plan in which the policyholder was enrolled at the time.',
#  'Major Medical Plan - Amounts shown here reflect what would have been reimbursed through the updated plans based on a $100 annual deductible.',
#  'Major Medical Plan - Available deductible amounts are $100, $250, $500 and $1,000.** rate discounts apply to the base medical plan only.† Premiums vary based on the age of the pet, species, size (as an adult), plan type, deductible and state of residence.Get your discount today** 877-PETS-VPI \uf09f www.petinsurance.com/abc All benefits in this booklet are subject to change.',
#  'Major Medical Plan - This is an Employee Benefits Guide and not a contract.',
#  'Major Medical Plan - All benefits are subject 23 to the provisions and exclusions of the master contract.',
#  'GLOSSARY - Brand Name Drug: A medication F l exible Medical Spending Account Open Enrollment: A period of time protected by patent for which a (FSA): A tax-advantaged account that when employees may make choices generic drug option is not available.',
#  'GLOSSARY - It can be used to pay for medical regarding their benefits for the is generally more expensive than a expenses.',
#  'GLOSSARY - Contributions to the FSA following year.',
#  'GLOSSARY - You should read generic equivalent.',
#  'GLOSSARY - are made by the employee.',
#  'GLOSSARY - The enrollment materials carefully, since contributions are free of federal, there are often substantial differences Social Security and most state taxes.',
#  'GLOSSARY - between health benefits plans.Coinsurance: The remaining portion Funds must be used in the year they of the cost of medical services to be are accrued; unused funds revert to paid by the patient after first meeting Out-of-Network Provider: Generally the employer.',
#  'GLOSSARY - Funds are not portable any applicable deductible(s).',
#  'GLOSSARY - refers to physicians, hospitals and and do not accrue interest.Coinsurance amounts, which are a other health care professionals who percentage of the cost, vary by type of have not contracted with a health plan service.',
#  'GLOSSARY - Formulary: A list of covered to provide services.',
#  'GLOSSARY - Employees pay prescription drugs.',
#  'GLOSSARY - Generally includes higher coinsurance rates for using an both brand name and generic out-of-network provider.Copay: A specific dollar amount that prescription drugs.',
#  'GLOSSARY - Within each you must pay for a specific service at category of covered drugs, there are the time when you receive the service.',
#  'GLOSSARY - PAD: Per Admission Deductible different levels of coverage based on the drug’s cost, efficacy or other considerations.Deductible: A fixed amount that an Premium (Insurance): The amount individual must pay for covered charged, per pay period, for medical medical services before the health insurance.',
#  'GLOSSARY - The cost of the premium is Generic Drug: A chemically equiva- plan will begin to pay.',
#  'GLOSSARY - shared between the employee and lent version of a brand-name drug for Company.',
#  'GLOSSARY - Your medical benefits are which the patent has expired.',
#  'GLOSSARY - Generic considered part of your total compen- drugs are typically less expensive, and',
#  'Dependent Care Spending Account: - sation (wages, vacation, training, etc.).are sold under the common name for Lets you set aside pre-tax dollars to the drug, not the brand name.pay for eligible childcare expenses.Because the reimbursement account Preventive Exam: Exams or services contributions are not taxed, you that can help maintain good health In-Network Provider: A physician, decrease your taxable income while (such as annual physical exams or hospital, nursing facility or other increasing your available cash.',
#  'Dependent Care Spending Account: - Funds immunizations) or are meant to detect health care provider that has do not roll over from year to year, are early signs of disease (such as contracted with Medical to provide not portable and do not accrue.',
#  'Dependent Care Spending Account: - mammograms and colon cancer covered services for a negotiated screenings).charge.Explanation of Benefits (EOB): A form provided directly to the member to',
#  'Mail Order Pharmacy: Distributes - explain how a health benefits claim prescribed medication directly to the was paid.',
#  'Mail Order Pharmacy: Distributes - In addition to claims patient via mail.payment information, the EOB often includes information on the appeals process.',
#  'Mail Order Pharmacy: Distributes - Maximum Out-of-Pocket: The limit on the amount an individual is re- quired to pay for health care services covered by their medical plan.',
#  'Mail Order Pharmacy: Distributes - Out-of- network, out-of-pocket maximums are higher than in-network maximums.All benefits in this booklet are subject to change.',
#  'Mail Order Pharmacy: Distributes - This is an Employee Benefits Guide and not a contract.',
#  'Mail Order Pharmacy: Distributes - All benefits are subject to the provisions and exclusions of the master contract.',
#  'Mail Order Pharmacy: Distributes - 24',
#  'Mail Order Pharmacy: Distributes - explain how a health benefits claim prescribed medication directly to the was paid.',
#  'Mail Order Pharmacy: Distributes - In addition to claims patient via mail.payment information, the EOB often includes information on the appeals process.',
#  'Mail Order Pharmacy: Distributes - Maximum Out-of-Pocket: The limit on the amount an individual is re- quired to pay for health care services covered by their medical plan.',
#  'Mail Order Pharmacy: Distributes - Out-of- network, out-of-pocket maximums are higher than in-network maximums.All benefits in this booklet are subject to change.',
#  'Mail Order Pharmacy: Distributes - This is an Employee Benefits Guide and not a contract.',
#  'Mail Order Pharmacy: Distributes - All benefits are subject to the provisions and exclusions of the master contract.',
#  'Mail Order Pharmacy: Distributes - 24',
#  'Benefit Guide Description - Please Note: This Employee Benefit Brochure is designed to provide a brief overview of the benefit plans that are provided for and made available to employees of the Company and their families.']

# %%
# Cleans the files and then resaves as a list

nlp = spacy.load("en_core_web_sm")

def clean_text(text):
    text = text.replace("’", "").replace("'", "")
    doc = nlp(text)
    cleaned_text = []

    for token in doc:
        # Lemmatize and lower the token
        lemmatized_token = token.lemma_.lower()

        # Check if the token is not space, not empty, not a vertical bar, not an apostrophe,
        # and is either a period, a hyphen, or non-punctuation
        if (not token.is_space and lemmatized_token and lemmatized_token not in ["|", "’", "'"] and 
            (lemmatized_token == '.' or lemmatized_token == '-' or not token.is_punct)):
            cleaned_text.append(lemmatized_token)

    # Join the cleaned tokens into a single string
    result = " ".join(cleaned_text)
    # Correct spaces before periods if any
    result = re.sub(r'\s+\.', '.', result)
    return result

def remove_duplicates(input_list):
    unique_list = []
    for item in input_list:
        if item not in unique_list:
            unique_list.append(item)
    return unique_list

bug_reporting_cleaned = remove_duplicates([clean_text(text) for text in bug_reporting_text if text.strip() != ''])
federal_holidays_cleaned = remove_duplicates([clean_text(text) for text in federal_holidays_text if text.strip() != ''])
benefit_guide_cleaned = remove_duplicates([clean_text(text) for text in benefit_guide_text if text.strip() != ''])
employee_handbook_cleaned = remove_duplicates([clean_text(text) for text in employee_handbook_text if text.strip() != ''])
training_policy_cleaned = remove_duplicates([clean_text(text) for text in training_policy_text if text.strip() != ''])

bug_reporting_cleaned
# Out:
# ['create bug reports coe - kg - xxx - bugs be deviation or defect note in the deployment or end - state of a system.',
#  'create bug reports coe - kg - xxx - they can be anything from a minor inconvenience to potentially catastrophic failure point.',
#  'create bug reports coe - kg - xxx - this article will guide you on how to go about handle bug and the creation of bug report in user story.',
#  'create bug reports coe - kg - xxx -',
#  'step to reproduce - indicate all the detail we need in order to see the bug.',
#  'step to reproduce - for instance by include screenshot and write down the step to recreate the issue we be able to allocate the right resource and assign the bug to the correct team.',
#  'step to reproduce - the step to reproduce or recreate should be a numbered list of the step that you take to notice the problem.',
#  'step to reproduce - the person who open the bug report will try these step and fix the problem if they can see it.',
#  'step to reproduce - however if they can not there be nothing they can do.',
#  'step to reproduce - this first step be call replicate a bug. the action you describe be vital to ensure that you can replicate bug before fix they.',
#  'step to reproduce - an example of step to reproduce might look like this uncomment the agent extension code at the bottom of the linuxvirtualmachine module deploy the vdc landing zone structure deploy the linuxvirtualmachine module or the 2tier - linux - app into a landing zone',
#  'note the expect vs. actual behavior - as the title explain within a bug report there should be a section where you describe what the expect behavior of a particular section of code system should be.',
#  'note the expect vs. actual behavior - and in contrast you should write a section explain the actual outcome result of execute the section of code.',
#  'note the expect vs. actual behavior - an example of expect vs.',
#  'note the expect vs. actual behavior - actual behavior may be expect behavior module complete successfully log datum from the vms w in 2tier - linux - app be supply to law via oms/ ama agent actual behavior module report failure during installation of vm extension you should experience the deployment hang - up on the 2 extension install never complete an error message indicate failure to list key for law will be present',
#  'include screenshots error messages in a bug report - screenshots error message capturing be a critical piece of a bug report because it show proof you observe the problem a general location start point to investigate the issue',
#  'example -',
#  'prioritize estimate bugs - we can not always determine the period of repair something that be break in an unknown way.',
#  'prioritize estimate bugs - therefore we estimate and prioritize the defect list into three main category the 3 priority high - bug that be affect the core functionality of the product medium - bug that have a workaround but degrade the core functionality of the product low - bug that do not affect critical core function of the product usually for cosmetic purpose',
#  'scenario - below be two example scenario for handle the defect by either assign a time window or refinement and estimation scenario 1 assign the timebox to the bug.',
#  'scenario - the team assign a fix number of hour dedicate to work on the bug service they base on the top priority within the list of bug.',
#  'scenario - in this scenario the team can handle one bug or five or an unlimited amount of bug.',
#  'scenario - there be no prediction on how many bug the team can do and no commitment to the delivery time.',
#  'scenario - but at the same time there be no time lose in investigate the bug.',
#  'scenario - scenario 2 refine the bug and estimate they in user story.',
#  'scenario - for clarification the bug be the misfunctioning of the product.',
#  'scenario - functionalities that be not present in the product must be handle with user story not with bug.',
#  'scenario - the nature of the flaw in software be very uncertain they can take a few minute as they can take an unestimated amount of time.',
#  'scenario - it might take more effort to find the root cause of a bug than actually fix it.',
#  'scenario - if you want to estimate a bug you first need to investigate the issue look into the code debug and isolate the problem.',
#  'scenario - if the team spend this effort during the refinement process and the entire team be involve it might be a waste of team effort.',
#  'scenario -',
#  'example of good bug report -',
#  'example of bad bug report -']

# %%
# Initialize OpenAIEmbeddings

embeddings_model = AzureOpenAIEmbeddings(
    azure_deployment="embedding",
    model="text-embedding-ada-002",
    azure_endpoint="https://cog-6v2xr4tg35qoy.openai.azure.com/",
    openai_api_type="azure",
    openai_api_key="a8120f3696c6450e9a376694b53f65df",
    openai_api_version="2023-03-15-preview"
)

# %%
# Function to embed a list of text chunks

def embed_chunks(chunks, embeddings_model, delay=0):
    embeddings = []
    for chunk in chunks:
        if chunk:
            embeddings.append(embeddings_model.embed_query(chunk))
            time.sleep(delay)
    return embeddings

# Embedding your text chunks
bug_reporting_embeddings = embed_chunks(bug_reporting_cleaned, embeddings_model)
federal_holidays_embeddings = embed_chunks(federal_holidays_cleaned, embeddings_model)
benefit_guide_embeddings = embed_chunks(benefit_guide_cleaned, embeddings_model)
employee_handbook_embeddings = embed_chunks(employee_handbook_cleaned, embeddings_model)
training_policy_embeddings = embed_chunks(training_policy_cleaned, embeddings_model)

# %%
# Combine all the embeddings and text chunks

all_embeddings = bug_reporting_embeddings + federal_holidays_embeddings + benefit_guide_embeddings + employee_handbook_embeddings + training_policy_embeddings
all_text_chunks = bug_reporting_cleaned + federal_holidays_cleaned + benefit_guide_cleaned + employee_handbook_cleaned + training_policy_cleaned

# %%
# Creates an embeddings list with the content from the text chunks

documents = []
for idx, (embedding, text_chunk) in enumerate(zip(all_embeddings, all_text_chunks)):
    document = {
        "id": idx,  # A unique identifier
        "embedding": json.dumps(embedding),  # The numerical embedding (might need flattening or serialization)
        "content": text_chunk  # The corresponding readable text chunk
    }
    documents.append(document)

# %%
# Initialize Azure AI Search

service_name = "anika-ai-search-v2"
index_name = "anika-data-index"
api_key = "D542TjWD97cVyrDoE4z747AWO6rQeZ0noxeHHiOd3TAzSeDyArrl"
api_version = "2023-11-01"  # Updated to the latest API version

# %%
# Send embeddings to Azure AI Search Data Index

# Endpoint URL for the Azure Search service
endpoint = f"https://{service_name}.search.windows.net/indexes/{index_name}/docs/index?api-version={api_version}"

# Preparing the payload for the POST request
# This payload consists of a list of documents to be indexed
payload = {
    "value": [
        {
            "@search.action": "upload", # Action type, here it's 'upload'
            "id": str(document["id"]),  # Convert 'id' to string
            "embedding": document["embedding"],  # String
            "content": document["content"]  # String
        } for document in documents
    ]
}

# Headers for the HTTP request
headers = {
    "Content-Type": "application/json",
    "api-key": api_key
}

def send_batch(endpoint, headers, batch):
    # Prepare the payload with the batch of documents
    payload = {"value": batch}

    # Send a POST request to the Azure Search service
    response = requests.post(endpoint, headers=headers, json=payload)

    # Check the response status and print appropriate messages
    if response.status_code in (200, 201):
        print("Batch successfully indexed.")
    else:
        print(f"Error in batch: {response.status_code} - {response.text}")

# Splitting the documents into batches and sending each batch
batch_size = 250  # Adjust this based on Azure AI Search limits
for i in range(0, len(documents), batch_size):
    batch = [
        {
            "@search.action": "upload",
            "id": str(doc["id"]),
            "embedding": doc["embedding"],
            "content": doc["content"]
        } for doc in documents[i:i+batch_size]
    ]
    # Sending the batch for indexing
    send_batch(endpoint, headers, batch)
# Out:
# Batch successfully indexed.
# Batch successfully indexed.
# Batch successfully indexed.
# Batch successfully indexed.
